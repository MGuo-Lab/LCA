# %% [markdown]
# # Translation of specification

# %% [markdown]
# These are notes on how we translate a specification of an optimisation problem for MOLA into an abstract Pyomo model that one can subsequently make concrete.

# %% [markdown]
# # Specification

# %% [markdown]
# This is the version 4 of the LP specification.

# %% [markdown]
# ## Indices and sets
#
# The index is a label that identifies an element in a set. For simplicity, we shall use the index to refer to the element that it indexes.

# %% [markdown]
# * $af \in AF$ is an index for an openLCA product flow imported from an openLCA database. This includes new flows that are defined by the user for the optimisation problem.
# * $f\in F$ is an index for a user-defined flow.
# * $f_m \in F_m \subset F$ is an index for a user-defined material flow (e.g. energy, material) to be considered in the optimisation problem.
# * $f_s \in F_s \subset F$ is an index for an user-defined service flow (e.g. energy storage, transport) to be considered in the optimisation problem.
# * $f_{t} \in F_{t} \subset F$ is an index for transport service flow i.e. transport mode \{road, train freight, air etc\}.
# * $l\in L$ location defined by Latitude and Longitude.
# * $e \in E$ is an elementary flow index for elementary flows imported from an openLCA database. A system process in the openLCA database is by definition broken down into a set of these elementary flows.
# * $ap \in AP$ is an index for a process in the set of all processes contained in an openLCA database. This include user-defined processes specifically designed for the optimisation tool.
# * $p\in P\subset AP$ is a process index for processes that make up the optimisation problem.
# * $t \in T$ is the time interval by time discretization $\{t_1, t_2, t_3, t_4 \ldots t_n\}$.
# * $k \in K$ a task index $k$ in the set of all task indices $K$.
# * $d \in D$ an index for a demand $d$ in the set of demand indices $D$.
# * $akpi \in AKPI$ is an indexes for all key performance indicators $KPI$ in an openLCA database. This includes key performance indicators defined by the user of the optimisation tool that must be added to the openLCA database.
# * $kpi \in KPI\subset AKPI$ is an index that identifies those performance indicators that the user wish to use in the optimisation problem.

# %% [markdown]
# ## Parameters

# %% [markdown]
# ### User-defined

# %% [markdown]
# * $C_{f_m, k, d, t}$ Conversion factor for material flows to generate per unit of demand product/services $d$ at task $s$, time $t$. If not defined default value is 0.
#
# * $D_{d,k,t}$ Demand for final product/service $d$ for task $k$ at time $t$; If not defined, default value is 0.
#
# * $D_{d,k}^{total}$ Total demand for final product/service over the whole optimisation time period over multiple tasks.
#
# * $L_{f_m, f_s}$ Binary factor to link services flows to material flows e.g. energy storage, material storage, transport; If not defined, default value is 0.
#
# * $X_{k, t}$ Longitude for where the material flow $f_m$ is transported in task $k$.
#
# * $Y_{k, t}$ Latitude for where the material flow $f_m$ is transported in the task $k$.
#
# * $d_{p,f_m, k, t}$ Total travel distance between process $p$ (where material flow $f_m$ is produced) and task $k$ (where material flow $f_m$ is transported to) at time $t$
#
# $$
# d_{p,f_m,k,t}=M(X_{k,t},Y_{k,t},X_{p, f_m}^I,Y^I_{p, f_m})
# $$
#
# where $M$ is a function that measures this distance e.g. Haversine - see http://www.movable-type.co.uk/scripts/latlong.html
#
#
# * $\phi_{f, p, t}$ Cost co-efficient for material, service and transport flows $f$ produced by $p$ at time t.

# %% [markdown]
# ### Imported from openLCA and model initialisation
#
# * $Ef_{akpi, e}$ Environmental impact characterisation factor for elementary flow $e$ and performance indicator $akpi$.
#
# * $EF_{e, f, p}$ Elementary flow $e$ to link with product flow $f$ through process $p$.
#
# * $EI_{akpi, f, ap}$ Calculated environmental impact for product flow $𝑓$ through process $ap$ and performance indicator $kpi$.
#
# * $X^I_{p,f_m}$ Longitude from the location table given in a process for material flow $f_m$.
#
# * $Y^I_{p,f_m}$ Latitude from the location table given in the process for material flow $f_m$.

# %% [markdown]
# ### Continuous variables

# %% [markdown]
# * $Obj_{kpi}$ Objective functions for the user-defined KPIs.
# * $Flow_{f_m, p,k, t}$ is the flow of material $f_m$ produced by process $p$ to task $k$ at time $t$.
# * $S_{f_s, k, t}$ is the temporary storage of service input flow $f_s$ at task $k$ and time $t$. **Perhaps call it $Service$ like $Flow$.**
# * $SF_{f_s, p, k, t}$ Specific service flow (e.g. storage) through process $p$ in task $k$ at time $t$.
# * $f_{f_m, p, f_t, k, t}$ Specific material and transport flow which is total quantity of materials $f_m$ produced in process $p$ transported through transport mode $f_t$ at task $k$ and time interval $t$ (unit: kg).
# * $T_{f_t,k,t}$ Transport flow which is quantity times distance of all materials transported through the transport mode $f_t$ at task $k$ and time interval $t$ (unit: kg km).
# * $t_{f_t,p,k,t}$ Specific transport flow which is quantity times distance of all materials transported through the transport mode $f_t$ and by process $p$ at task $k$ and time interval $t$ (unit: kg km).

# %% [markdown]
# ## Objective function

# %% [markdown]
# Our objective is to minimise the environmental impact of elementary flows and the economic cost derived from a network of processes.
#
# Consequently, the objective is for a fixed impact category $kpi$

# %% [markdown]
# $$
# \min_D Obj_{kpi}
# $$
#
# and
#
# $$
# \min_D Obj_{cost}
# $$
#
# where the decision variables are defined by the set
#
# $$
# D=\cup_{F,P,K,T}\{SF_{f_s, p, k, t}, f_{f_m,f_t,k,t}, t_{f_t, p, k, t}\}
# $$
#
# and represent the specific service flows, the specific material flows using a mode of transport, and the specific transport flows.

# %% [markdown]
# The environmental impact is the sum of the environmental impacts arising from material, service flows, and transport flows:

# %% [markdown]
# $$
# Obj_{kpi} = \sum_{f_m, p_m, k, t} Flow_{f_m, p_m, k, t}EI_{kpi, f_m, p_m} +
# \sum_{f_s, p_s, k ,t} SF_{f_s, p_s, k, t}EI_{kpi, f_s, p_s} +
# \sum_{f_t, p_t, k, t}t_{f_t, p_t, k, t}EI_{kpi,f_t,p_t}.
# $$

# %% [markdown]
# The economic impact is the sum of the economic impacts arising from material, service and transport flows:

# %% [markdown]
# $$
# Obj_{cost} = \sum_{f_m, p_m, k, t} Flow_{f_m, p_m, k, t}\phi_{f_m, p_m, t} +
# \sum_{f_s, p_s, k, t} SF_{f_s, p_s, k, t}\phi_{f_s, p_s, t} +
# \sum_{f_t, p_t, k, t}t_{f_t, p_t, k, t}\phi_{f_t, p_t, t}
# $$

# %% [markdown]
# Here the environmental impact of flow $f\in F$ measured by impact factor $kpi$ is

# %% [markdown]
# $$
# EI_{kpi, f, p} = \sum_e Ef_{kpi, e}EF_{e, f, p}
# $$
#
# where the flow $f$ is the product flow for the process $p\in P$. Here $Ef_{kpi, e}$ denotes the impact factor indexed by impact category $kpi$ and environmental flow $e$ and $EF_{e, f, p}$ is the quantity of elementary flow generated by the product flow $f$ by process $p$. If $f\in F_m\cup F_s\cup F_t$ then the breakdown of flow into elementary flow amounts $EF_{e, f, p}$ must be calculated in openLCA by constructing a *system process*, which is then imported into the optimisation tool. Otherwise the flow is a product flow from an existing system process in openLCA so there already is a breakdown.

# %% [markdown]
# ## Constraints

# %% [markdown]
# The binary parameter $L_{f_m, f_s}$ determines the linkage between storage service flow $S_{f_s, k,t}$ and the material
# storage flow $S_{f_m, k, t}$ at task $k$ and time $t$:
#
# $$
# S_{f_s,k,t} = \sum_{f_m} L_{f_m, f_s}S_{f_m, k, t},
# $$
#
# where $L_{f_m, f_s}$ is a binary parameter than links the service flow $f_s$ to the material flow $f_m$  in task $k$ at time $t$.
#
# The service flow $S_{f_s, k,t}$ is the sum of the process specific service flows $SF_{f_m, p, k, t}$:
#
# $$
# S_{f_s,k,t} = \sum_{f_m, p_m} SF_{f_m, p_m, k, t},\quad \text{needs an $f_s$ here?}
# $$
#
# For any material flow $f_m$ produced by $p$, the total quantity $Flow_{f_m,p,k,t}$ is dependent on the quantity of $f_m$ transported through transport mode $f_t$ at task $k$ and time interval $t$, which is denoted by $f_{f_m,p_m,f_t,k,t}$.
#
# $$
# Flow_{f_m,p_m,k,t}=\sum_{f_t} f_{f_m,p_m,f_t,k,t}
# $$
#
# The transport flow $T_{f_t,k,t}$ is defined by the quantity of $f_m$ transported via transport mode $f_t$ at task $k$ and time interval $t$ and the transport distance for shipping $f_m$ from initial production location $(X^I_{p,f_m},Y^I_{p,f_m})$ to final task location $X_{k,t}, Y_{k,t}$.
#
# $$
# T_{f_t, k, t} = \sum_{f_m, p_m} f_{f_m, p_m, f_t, k, t}d_{p, f_m, k, t}
# $$
#
# The transport flow is also the sum of the specific transport flows denoted by $t_{f_t, p_t, k, t}$:
#
# $$
# T_{f_t, k, t} = \sum_{p_t} t_{f_t, p_t, k, t}
# $$
#
# The sum of material flows over each production process and the conversion of temporary storage to material flow must satisfy demand
#
# $$
# \sum_{f_m, p} (Flow_{f_m, p, k, t} - S_{f_m, k, t} + S_{f_m, k, t-1})C_{f_m, k, t} \geq D_{d,k,t}
# $$
#
# The total material flow minus final storage must satisfy the total demand over the time horizon so
#
# $$
# \sum_{f_m,p,t} Flow_{f_m, p, k, t}C_{f_m, k, t}  \geq D_{d,k}^{total}.
# $$
#
# Finally, we require
#
# $$
# SF_{f_s, k, t} \geq 0,
# $$
#
# $$
# f_{f_m, p, f_t, k, t} \geq 0,
# $$
#
# $$
# t_{f_t, p, k, t} \geq 0.
# $$

# %% [markdown]
# # Abstract Pyomo Model
#
# The specification is translated into an abstract pyomo model.

# %%
from importlib import reload
from pyomo.environ import *
abstract_model = AbstractModel()

# %% [markdown]
# ## Indices and sets

# %% [markdown]
# There is no instantiation of sets just placeholders for data. Some of the data must be supplied by the user via a GUI or programmatically and some must come from a data source.

# %% [markdown]
# ### User-defined
#
# These are placeholders for the GUI.

# %%
abstract_model.F = Set(doc='Flows to optimise')
abstract_model.F_m = Set(doc='Material flows to optimise')
abstract_model.F_s = Set(doc='Service flows to optimise')
abstract_model.F_t = Set(doc='Transport flows to optimise')
abstract_model.P = Set(doc='Processes in the optimisation problem')
abstract_model.T = Set(doc='Time intervals')
abstract_model.K = Set(doc='Tasks')
abstract_model.D = Set(doc='Demands')
abstract_model.KPI = Set(doc='Performance indicators for optimisation problem')

# %% [markdown]
# ### DB DataPortal
#
# These sets are populated by reference ids from openLCA.

# %%
abstract_model.AF = Set(doc='All flows in openLCA database')
abstract_model.E = Set(doc='Elementary Flows in OpenLCA database')
abstract_model.AP = Set(doc='All processes from in OpenLCA database')
abstract_model.AKPI = Set(doc='All key performance indicators in an openLCA database')

# %% [markdown]
# So to generate a new model instance in the GUI the user first needs to specify an openLCA database. This will populate dropdowns so the user can make choices.
#
# We use a DataPortal and to populate the sets.

# %%
olca_dp = DataPortal()
db_file = '/mnt/disk1/data/openlca/sqlite/system/CSV_juice_ecoinvent_36_apos_lci_20200206_20201029-102818.sqlite'
olca_dp.load(filename=db_file, using='sqlite3', query="SELECT REF_ID FROM TBL_FLOWS", set=abstract_model.AF)
olca_dp.load(filename=db_file, using='sqlite3', query="SELECT REF_ID FROM TBL_FLOWS WHERE FLOW_TYPE='ELEMENTARY_FLOW'", set=abstract_model.E)
olca_dp.load(filename=db_file, using='sqlite3', query="SELECT REF_ID FROM TBL_PROCESSES", set=abstract_model.AP)
olca_dp.load(filename=db_file, using='sqlite3', query="SELECT REF_ID FROM TBL_IMPACT_CATEGORIES", set=abstract_model.AKPI)
model_instance = abstract_model.create_instance(olca_dp)

# %% [markdown]
# We shall also need flow/process names and categories and other data which may need more complicated queries that don't fall under the capabilities of a DataPortal. This supplementary data is obtained using a query builder. For example, the following function builds dictionaries for mapping reference ids to names.

# %%
import mola.dataimport as di
import mola.dataview as dv
reload(dv)

dbconn = di.get_sqlite_connection()
d = dv.get_ref_id_dicts(dbconn, {'flows': 'TBL_FLOWS', 'processes': 'TBL_PROCESSES'})
d['flows']['0f440cc0-0f74-446d-99d6-8ff0e97a2444']
# Out:
# SELECT "REF_ID","NAME" FROM "TBL_FLOWS"
# SELECT "REF_ID","NAME" FROM "TBL_PROCESSES"
# SELECT "REF_ID","NAME" FROM "TBL_FLOWS" WHERE "FLOW_TYPE"='PRODUCT_FLOW'
# 'Ammonia'

# %% [markdown]
# We might be able to use the existing DataPortal to load this data, but it is not
# clear if it is possible to load indexed sets from sqlite. We could load them into tuple sets and transform.

# %%
# model = AbstractModel()
# model.I = Set()
# model.A = Set(dimen=1)
# data = DataPortal()
# data.load(filename='A.tab', set=model.A, index=[1,2,3])
# instance = model.create_instance(data)
# instance.A.pprint()
# instance.B = Set()

# cmodel = ConcreteModel()
# cmodel.B = Set(initialize=['b1', 'b2'])
# cmodel.C = Set(cmodel.B, initialize={'b1':['c1'], 'b2': ['c4','c2']})
# cmodel.C.pprint()
# cmodel.C['b1'].pprint()

# %%
# concrete_model = ConcreteModel()
# concrete_model.AF1 = Set(initialize=model_instance.AF)
# olca_dp.load(filename=db_file, using='sqlite3', query="SELECT NAME AS AF1 FROM TBL_FLOWS", 
#              set=concrete_model.AF, index=concrete_model.AF)
#concrete_model.AF1.pprint()

# %% [markdown]
# ## Parameters

# %% [markdown]
# ### User-defined
#
# These are defined by the GUI so they are placeholders.

# %%
abstract_model.C = Param(abstract_model.F_m, abstract_model.K, abstract_model.D, abstract_model.T,
                         doc='Conversion factor for material flows')
abstract_model.Demand = Param(abstract_model.D, abstract_model.K, abstract_model.T)
abstract_model.Total_Demand = Param(abstract_model.D, abstract_model.K)
abstract_model.L = Param(abstract_model.F_m, abstract_model.F_t)
abstract_model.X = Param(abstract_model.K, abstract_model.T)
abstract_model.Y = Param(abstract_model.K, abstract_model.T)
abstract_model.d = Param(abstract_model.P, abstract_model.F_m, abstract_model.K, abstract_model.T)
abstract_model.phi = Param(abstract_model.F, abstract_model.P, abstract_model.T)

# %% [markdown]
# ### DB DataPortal
#
# We cannot just load these when the database is specified because they depend on user input. They are completed in the model build phase after user definition.

# %%
abstract_model.Ef = Param(abstract_model.AKPI, abstract_model.E)
abstract_model.EF = Param(abstract_model.E, abstract_model.F, abstract_model.P)
abstract_model.EI = Param(abstract_model.AKPI, abstract_model.F, abstract_model.E)
abstract_model.XI = Param(abstract_model.P, abstract_model.F_m)
abstract_model.YI = Param(abstract_model.P, abstract_model.F_m)

# %% [markdown]
# ## Variables
#
# These can be defined in the abstract model, but we are likely to use linked sets to decrease the amount of redundancy.

# %%
abstract_model.Flow = Var(abstract_model.F_m, abstract_model.P, abstract_model.K, abstract_model.T)
abstract_model.Storage = Var(abstract_model.F_s, abstract_model.K, abstract_model.T)
abstract_model.Service_Flow = Var(abstract_model.F_s, abstract_model.P, abstract_model.K, abstract_model.T)
abstract_model.Specific_Material_Transport_Flow = Var(abstract_model.F_m, abstract_model.P, abstract_model.F_t, 
                                             abstract_model.K, abstract_model.T)
abstract_model.Transport_Flow = Var(abstract_model.F_t, abstract_model.K, abstract_model.T)
abstract_model.Specific_Transport_Flow = Var(abstract_model.F_t, abstract_model.P, abstract_model.K, abstract_model.T)

# %% [markdown]
# ## Objective

# %% [markdown]
# There are two objectives in the abstract model. They are constructed at build time.

# %%
def environment_objective_rule(model, kpi):
    return sum(model.Flow[fm, p, k, t]*model.EI[kpi, fm, p]
               for fm in model.F_m for p in model.P for k in model.K for t in model.T) + \
            sum(model.Service_Flow[fs, p, k, t] * model.EI[kpi, fs, p]
                for fs in model.F_s for p in model.P for k in model.K for t in model.T) + \
            sum(model.Specific_Transport_Flow[ft, p, k, t] * model.EI[kpi, ft, p]
                for ft in model.F_t for p in model.P for k in model.K for t in model.T)

def cost_objective_rule(model):
    return sum(model.Flow[fm, p, k, t]*model.phi[fm, p, t]
               for fm in model.F_m for p in model.P for k in model.K for t in model.T) + \
            sum(model.Service_Flow[fs, p, k, t] * model.phi[fs, p, t]
                for fs in model.F_s for p in model.P for k in model.K for t in model.T) + \
            sum(model.Specific_Transport_Flow[ft, p, k, t] * model.phi[ft, p, t]
                for ft in model.F_t for p in model.P for k in model.K for t in model.T)

abstract_model.obj1 = Objective(abstract_model.KPI, rule=environment_objective_rule)
abstract_model.obj2 = Objective(rule=cost_objective_rule)
abstract_model.obj1.pprint()
abstract_model.obj2.pprint()
# Out:
# obj1 : Size=0, Index=KPI, Active=True
#     Not constructed
# obj2 : Size=0, Index=None, Active=True
#     Not constructed

# %% [markdown]
# ## Constraints
#
# These are determined at build time from information in the GUI. There is no indexing of sets at present.

# %%
def flow_demand_rule(model, d, k):
    total_demand = sum(
        model.Flow[fm, pm, k, t] * model.C[fm, k, t] for fm in model.F_m for pm in model.P for t in model.T)
    return total_demand >= model.Total_Demand[d, k]
abstract_model.total_demand_constraint = Constraint(
    abstract_model.D, abstract_model.K, rule=flow_demand_rule)

def material_flow_rule(model, fm, pm):
    return model.Flow[fm, pm, k, t] == sum(model.f[fm, pm, ft, k, t] for ft in model.ft)
abstract_model.material_flow_constraint = Constraint(abstract_model.F_m, abstract_model.P, expr=material_flow_rule)

abstract_model.transport_constraint = ConstraintList()
abstract_model.specific_transport_constraint = ConstraintList()

# %% [markdown]
# # User configuration
#
# The mola specification module contains a class called ScheduleSpecification that contains the above abstract model.

# %%
import mola.specification as ms
spec = ms.ScheduleSpecification()
spec.abstract_model.pprint()
# Out:
# 33 Set Declarations
#     AF : All flows in openLCA database
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     AKPI : All key performance indicators in an openLCA database
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     AP : All processes from in OpenLCA database
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     C_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     D : Demands
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     Demand_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     E : Elementary Flows in OpenLCA database
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     EI_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     F : Size=0, Index=None, Ordered=True
#         Not constructed
#     F_index_0 : Size=0, Index=None, Ordered=True
#         Not constructed
#     F_m : Material flows to optimise
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     F_s : Service flows to optimise
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     F_t : Transport flows to optimise
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     Flow_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     K : Tasks
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     KPI : Performance indicators for optimisation problem
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     L_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     P : Processes in the optimisation problem
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     Service_Flow_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     Specific_Material_Transport_Flow_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     Specific_Transport_Flow_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     Storage_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     T : Time intervals
#         Size=0, Index=None, Ordered=Insertion
#         Not constructed
#     Total_Demand_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     Transport_Flow_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     X_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     Y_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     d_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     material_flow_constraint_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     phi_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     specific_transport_constraint_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     total_demand_constraint_index : Size=0, Index=None, Ordered=True
#         Not constructed
#     transport_constraint_index : Size=0, Index=None, Ordered=True
#         Not constructed
#
# 9 Param Declarations
#     C : Conversion factor for material flows
#         Size=0, Index=C_index, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     Demand : Size=0, Index=Demand_index, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     EI : Size=0, Index=EI_index, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     L : Size=0, Index=L_index, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     Total_Demand : Size=0, Index=Total_Demand_index, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     X : Size=0, Index=X_index, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     Y : Size=0, Index=Y_index, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     d : Size=0, Index=d_index, Domain=Any, Default=None, Mutable=False
#         Not constructed
#     phi : Size=0, Index=phi_index, Domain=Any, Default=None, Mutable=False
#         Not constructed
#
# 6 Var Declarations
#     Flow : Size=0, Index=Flow_index
#         Not constructed
#     Service_Flow : Size=0, Index=Service_Flow_index
#         Not constructed
#     Specific_Material_Transport_Flow : Size=0, Index=Specific_Material_Transport_Flow_index
#         Not constructed
#     Specific_Transport_Flow : Size=0, Index=Specific_Transport_Flow_index
#         Not constructed
#     Storage : Size=0, Index=Storage_index
#         Not constructed
#     Transport_Flow : Size=0, Index=Transport_Flow_index
#         Not constructed
#
# 2 Objective Declarations
#     obj1 : Size=0, Index=KPI, Active=True
#         Not constructed
#     obj2 : Size=0, Index=None, Active=True
#         Not constructed
#
# 4 Constraint Declarations
#     material_flow_constraint : Size=0, Index=material_flow_constraint_index, Active=True
#         Not constructed
#     specific_transport_constraint : Size=0, Index=specific_transport_constraint_index, Active=True
#         Not constructed
#     total_demand_constraint : Size=0, Index=total_demand_constraint_index, Active=True
#         Not constructed
#     transport_constraint : Size=0, Index=transport_constraint_index, Active=True
#         Not constructed
#
# 54 Declarations: F_m F_s F_t F_index_0 F P T K D KPI AF E AP AKPI C_index C Demand_index Demand Total_Demand_index Total_Demand L_index L X_index X Y_index Y d_index d phi_index phi EI_index EI Flow_index Flow Storage_index Storage Service_Flow_index Service_Flow Specific_Material_Transport_Flow_index Specific_Material_Transport_Flow Transport_Flow_index Transport_Flow Specific_Transport_Flow_index Specific_Transport_Flow obj1 obj2 total_demand_constraint_index total_demand_constraint material_flow_constraint_index material_flow_constraint transport_constraint_index transport_constraint specific_transport_constraint_index specific_transport_constraint

# %% [markdown]
# The class contains a method to generate lookup tables.

# %%
import mola.dataview as dv
import mola.dataimport as di
conn = di.get_sqlite_connection()
lookup = dv.get_lookup_tables(conn)
# Out:
# SELECT "REF_ID","NAME" FROM "TBL_FLOWS"
# SELECT "REF_ID","NAME" FROM "TBL_PROCESSES"
# SELECT "REF_ID","NAME" FROM "TBL_CATEGORIES"
# SELECT "REF_ID","NAME" FROM "TBL_FLOWS" WHERE "FLOW_TYPE"='PRODUCT_FLOW'

# %% [markdown]
# We can use the lookups to build a user interface. For example, we can populate a widget with all material flows and then ask a user to select a subset.

# %%
import pandas as pd, IPython.display as d, ipywidgets as widgets
import qgrid

in_df = lookup['product_flows']
in_qg = qgrid.show_grid(in_df, grid_options={'maxVisibleRows': 10})
out_df = pd.DataFrame()
out_qg = qgrid.show_grid(out_df, grid_options={'maxVisibleRows': 10})
button1 = widgets.Button(description='Add to set')
button2 = widgets.Button(description='Remove from set')

def on_button_clicked1(b):
    dfr = out_qg.df.append(in_qg.get_selected_df())
    out_qg.df = dfr
button1.on_click(on_button_clicked1)
def on_button_clicked2(b):
    dfr = out_qg.df.drop(out_qg.get_selected_rows())
    out_qg.df = dfr
button2.on_click(on_button_clicked2)

d.display(button1)
d.display(in_qg)
d.display(button2)
d.display(out_qg)
# Out:
# Button(description='Add to set', style=ButtonStyle())
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
# Button(description='Remove from set', style=ButtonStyle())
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
if len(out_qg.df) > 0:
    F_m = out_qg.df.index.to_list()
else:
    F_m = ['f1', 'f2']

# %% [markdown]
# We need some dummy data to do instantiation of the abstract model. The specificaton has a method to return a suitable set of data. The model parameters are dependent on the sets that the user defines.
#
# In practice, we want to persist the model so we store user data in a JSON file.

# %%
import json
user_data = spec.get_dummy_data({'F_m': F_m})
json_file = 'user_data.json' 
with open(json_file, 'w') as fp:
    json.dump(user_data, fp)
user_data
# Out:
# {'F_m': ['f1', 'f2'],
#  'F_s': ['ft1'],
#  'F_t': ['fs1'],
#  'D': ['d1'],
#  'T': ['t1'],
#  'K': ['k1'],
#  'P': ['p1'],
#  'KPI': ['kpi1'],
#  'OBJ': ['environment', 'cost'],
#  'F': ['f1', 'f2', 'ft1', 'fs1'],
#  'C': [{'index': ['f1', 'k1', 't1'], 'value': 2},
#   {'index': ['f2', 'k1', 't1'], 'value': 2}],
#  'd': [{'index': ['p1', 'f1', 'k1', 't1'], 'value': 2},
#   {'index': ['p1', 'f2', 'k1', 't1'], 'value': 2}],
#  'Total_Demand': [{'index': ['d1', 'k1'], 'value': 1}],
#  'EI': [{'index': ['kpi1', 'f1', 'p1'], 'value': 1},
#   {'index': ['kpi1', 'f2', 'p1'], 'value': 1},
#   {'index': ['kpi1', 'ft1', 'p1'], 'value': 1},
#   {'index': ['kpi1', 'fs1', 'p1'], 'value': 1}],
#  'phi': [{'index': ['f1', 'p1', 't1'], 'value': 1},
#   {'index': ['f2', 'p1', 't1'], 'value': 1},
#   {'index': ['ft1', 'p1', 't1'], 'value': 1},
#   {'index': ['fs1', 'p1', 't1'], 'value': 1}]}

# %% [markdown]
# # Build Phase
#
# In this phase we add data to the abstract model so generate a concrete model instance.

# %%
db_file = '/mnt/disk1/data/openlca/sqlite/system/CSV_juice_ecoinvent_36_apos_lci_20200206_20201029-102818.sqlite'
model_instance = spec.populate(db_file, json_file)
model_instance.pprint()
# Out:
# WARNING: DEPRECATED: Providing construction data to SetOperator objects is
#     deprecated.  This data is ignored and in a future version will not be
#     allowed  (deprecated in 5.7) (called from
#     /opt/tljh/user/lib/python3.7/site-
#     packages/pyomo/core/base/PyomoModel.py:883)
# 33 Set Declarations
#     AF : All flows in openLCA database
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any : 7033 : {'dcb70fd5-e305-4920-b68b-40697cc6a206', '0f440cc0-0f74-446d-99d6-8ff0e97a2444', 'e336eee7-148a-4d1c-8027-780cbfafa12b', 'e6551223-73b6-4289-b841-c5cdeb25abd9', '33b38ccb-593b-4b11-b965-10d747ba3556', 'afd6d670-bbb0-4625-9730-04088a5b035e', '70ef743b-3ed5-4a6d-b192-fb6d62378555', '66f50b33-fd62-4fdd-a373-c5b0de7de00d', '099b36ab-4c03-4587-87f4-2f81e337afb8', 'aa7cac3a-3625-41d4-bc54-33e2cf11ec46', '4d40d8e3-9bc7-4ab1-ac5c-4f4a76fda8e5', 'ada3ecfe-8244-4389-bcce-e83ca4f66e09', '81c4ba39-8a3f-4a43-97b4-401605bbebf5', '13d898ac-b9be-4723-a153-565e2a9144ac', '77357947-ccc5-438e-9996-95e65e1e1bce', '5e883a00-04e6-4d96-8dce-12d7117c6635', 'e8fc62ba-678e-4706-97d2-b79d83e227d5', '78c3efe4-421c-4d30-82e4-b97ac5124993', 'e2d58f90-9aac-4ac4-87f7-bbd6cfc358e3', '78eb1859-abd9-44c6-9ce3-f3b5b33d619c', '68b9b577-90cf-49e4-88bb-a55d80f3ac5d', '0d3ccb17-b3fe-4c08-b7cb-458ed3ababf1', 'fc9f9a81-c4b9-4dce-bc20-9f04e05ca2f1', '7a2d7097-20c4-4b5f-b2ee-bcfc2ba1378f', 'c5cc0625-6e01-4639-b053-5d1d9d22a53c', 'f7553ef8-e4f3-4b9c-98be-81fa36315648', '10b69d7a-018d-44c6-9a5e-e67fc9475b86', '23856318-9583-426b-ab04-12e4506b60a8', '9beb60a3-3a8c-4345-9a0e-107eec2f709f', '295c9740-6fdb-4676-9eb8-15e3786f713d', '63974d2c-11f3-45eb-be9c-726261b04d85', 'a1d277aa-7aea-4b5e-8aa9-2789ba8ff333', '77f17646-cede-4a49-99dd-55950098b077', 'bf633941-aa40-4c37-b361-b5cbfb1089f5', '9541a975-800f-4fed-9edf-28f6e411a015', '1d2439de-751b-469a-ba3e-fda8fe9802b2', 'e7e0031e-791d-42f4-b26c-ec322db637bc', '87f683ed-44ae-41a6-b4bc-230622f8cfef', '9167dca7-615e-435c-8ba6-dbbf50e50e34', 'e64254e3-07d3-4330-b6de-6a858f108124', '142ce3b0-4bd6-47a3-9991-7c657c947ffe', '9e8d685c-9948-4dc0-9c0b-d5c511e14d05', 'e0e605c8-370b-4b5a-b6d4-2e7a5a1a6709', 'e7f7fd97-a1c8-4be9-8a21-68ef06437d20', '0437e787-ef47-4a50-b11f-df7c743e860c', 'd24f41d7-279e-4f5a-9ac9-00f726dc3bcc', 'f77c5e36-ee47-4437-b757-03139bb1d6d6', 'ba5fc0b6-770b-4da1-9b3f-e3b5087f07cd', '03b279a7-4626-4703-a451-d0650599dbd9', 'b821ad93-ba6a-4d74-b6ae-ca12cd9563d7', 'dc46afa7-0142-49e8-a353-ab6a1327bbc8', '3d719c07-ec27-4971-b7cc-4bcf17d77dd3', 'a028cff8-e405-4d44-8322-f46e9e51bcdc', 'c76ddd9e-fd9c-47c5-9b95-ad924146f0bb', '9597c1a2-ecda-4a89-97c5-efcdc679058d', '2460f868-54a9-404c-bec8-c809a44ae72c', '7348af7c-e102-4a03-a0df-efce16469eed', '2d50f4c8-a917-4496-a7d9-470b080faf68', '5ec9c16a-959d-44cd-be7d-a935727d2151', '15fd8f0f-c3c2-4f63-b8d0-86793a22aacd', '2718482b-8399-442e-b89a-52fbcc22d2e6', 'd6235194-e4e6-4548-bfa3-ac095131aef4', 'ea4e9316-5080-4b3b-bbf3-1949f6d7577a', '17a98e7f-a8fd-431d-9bb6-6c4bf3fc5517', 'b8d738ce-98cd-4487-88f9-686209bd1376', 'd32f9dd8-9514-4c22-8c99-2e108609731f', '57bdb443-d4a6-423d-8024-959b8261d02e', '09872080-d143-4fb1-a3a5-647b077107ff', '075e433b-4be4-448e-9510-9a5029c1ce94', '21b46c65-491e-40a9-ac74-5877af997d7c', 'b967e1bf-f09b-4c89-8740-ace21db47bba', '71234253-b3a7-4dfe-b166-a484ad15bee7', 'c1b91234-6f24-417b-8309-46111d09c457', 'fd7aa71c-508c-480d-81a6-8052aad92646', '5d368100-b1bc-4456-8420-e469edccf349', '66020d27-7ae4-4e59-83a3-89214b72c40a', '21e46cb8-6233-4c99-bac3-c41d2ab99498', 'c941d6d0-a56c-4e6c-95de-ac685635218d', '082903e4-45d8-4078-94cb-736b15279277', '4841a0fe-c250-4a39-94a1-1bc31426c0f1', '39d1390a-ded6-41cb-a536-d47510bf2fbc', 'd14eb0da-95fd-46c3-90db-55ca33d78701', '20d4d821-f4f7-4017-8810-f822fcdf619e', 'd761f94e-517d-41cf-89fa-17dc72f7a69b', '24541c8c-9f11-49ae-9de5-456f238a3f5e', '87883a4e-1e3e-4c9d-90c0-f1bea36f8014', '20185046-64bb-4c09-a8e7-e8a9e144ca98', '2058d91e-bb9f-4fce-8e53-131825b14a23', '35d1dff5-b535-4628-9826-4a8fce08a1f2', 'ba2f3f82-c93a-47a5-822a-37ec97495275', 'd3260d0e-8203-4cbb-a45a-6a13131a5108', '0795345f-c7ae-410c-ad25-1845784c75f5', '7678cec7-b8e1-439d-8242-99cd452834b1', '349b29d1-3e58-4c66-98b9-9d1a076efd2e', 'f2d84834-d0b3-42e5-b41a-f04cc80337a4', '81e17d9a-3e0b-414e-9b2e-eca7e5b3bd4a', '20557d93-2b1c-49b5-b6c0-3528a8bbc307', '591b0a62-8064-4697-86ed-47bfa1f8b5e6', '1c5a7322-9261-4d59-a692-adde6c12de92',  ...
#     AKPI : All key performance indicators in an openLCA database
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :  878 : {'33c38a7c-38fa-32ee-a3e5-f22313710186', '02da642e-1bea-361b-8ce8-72fc3ba441bb', '8c435a6c-ee1f-3dfc-8534-6db4c9280958', '7ff00266-4216-3f96-a369-f2aef2b5e75c', '119cb7a3-7c96-396d-a91e-c960ea7e8932', 'e5089ba7-4857-34bc-9020-0329a45193b7', 'af4b4b7a-9b85-314c-b686-7766448366f0', '61a78a25-68bf-392c-a10a-3befef762aa8', '4d3ea0f3-f59c-3f9d-9128-7e79ac38ea31', '26987606-68bb-3552-91ec-a8588b4c080b', 'c27011d5-8136-39b9-bd9e-f220c1eda1ca', '10c823ce-fd51-3de0-9a1f-8ee20b6863e1', '26fef6db-726d-33ad-a244-3b39a3dc95c2', 'f1b88046-332f-353f-8713-b9d64e10dd63', 'dc8ded3e-cd29-3cc2-af92-80ce5a771db0', 'd50d507d-23fb-36f8-9bdc-60afa2a644dc', 'a312d733-c65e-3259-8a7d-578b3ed8ed24', 'be8b2540-2d8f-35bb-9c42-51b8ef9f4b66', '8e47ca05-e161-3ad1-a20c-f8411d28d34f', '73b8ce84-c8f9-34cb-b992-a04e61cc8554', '8c95530e-8738-3bc3-945a-e33ba57043a4', '7fa256e1-594f-334f-b2f7-59d21116cf1d', '3f1b3859-372b-33be-a3d3-734c5c3a0d2d', '8390068f-7f90-32c6-989e-b2746794f5a2', 'a4f27455-291d-30fd-a4e4-0fce4c3f144e', '944f8421-1cc1-35d4-afdd-eea09b78ce42', '85060a1d-509e-32bb-99e4-c1b0778a4606', 'c97d3bfd-e5a7-3dc2-a87b-76a903d8ab17', '045c076d-40ec-37fd-a534-8d0174031db6', '88f25a0e-380c-3960-9063-7bce062a2911', '03eec95a-d94f-3924-bfba-7fbde764b6d9', '5f07a020-a3a1-3179-90a3-d32c040ce83c', '077d7fe6-17c3-3ece-9f40-adf760e7cfaa', '9aec3040-3d49-36d2-8903-f02e670cdd1e', '61fc4b9f-6946-3dd3-abb8-ab6fef9d32d7', '201d812d-c3ee-3fb3-9dbd-0a5cd2f0948b', '0e54d54c-fdcb-35d7-aca2-cc3586eee3e7', 'f5b9a19b-22c9-3599-8630-5cada8b0efc4', '48b0d25c-e39a-3173-b992-4875bea59037', '7b1f44d7-9386-39fa-9186-a186a8b16e1f', '99f1faa7-6366-3c86-9d82-59ecdf4a6f4e', '8e4d8326-20a0-3c43-ab95-59e3988a3758', '62034873-178d-39f9-8f51-670b04545e79', 'b197e972-cf0a-3c3b-91dc-4ebd7b87373c', '7231b3eb-e78e-33ea-8dd9-a3e654498d4e', '7da79a85-cb4e-3ed2-9c58-e1a5fffec544', '1408fbd0-9e31-3cf6-9c9b-755ce7bd6e6a', '40925f79-6876-3532-b6ab-f8fc37201fbb', 'e7045821-d8f3-3fde-b749-abee8cce9d73', '2572d144-5e11-30ff-800d-2fc10a935555', 'c7ab8428-2f9c-3229-90c4-f0cdf9626377', '010855f5-22fa-33fd-b936-83449a76b984', '5d1dda8b-6e40-395b-8a75-a4655c263fa8', 'abbcf28f-011e-35bf-9857-38c05000817f', '2c802bae-2b8e-34cc-8d58-3513a68fa80c', '7dc53f69-2370-39b2-937d-6ff5247d8ee0', '73806bd6-1601-3d67-bde8-cd6bb01f3a10', '9120eff7-b409-3d67-b9ad-38bff7069599', '59861152-1e03-38e4-8a5e-d546b262d88b', 'e0598d4a-61ec-3994-85d8-a31ec082018d', '054dea47-17b2-3752-bcb9-82bc3cfa820a', '3e971a09-3586-3d13-83f2-0d964a738c20', '4964dad1-7d73-3024-a501-83e9ce93510b', 'ad74382a-add4-35c8-b373-7f8dedc80733', '3454f174-9c02-3f6e-9c5f-0911529d9c11', 'bf568b19-cd47-3973-b8d9-cf9df29fa6e5', '08257864-cfba-3e84-a24d-3429a00af389', '41b12ce8-51e3-3fb4-af12-27b9d69dc349', '811a6af4-adf2-356e-8945-e9e7bad08397', '0f14a927-06eb-37c8-a339-a5afbb027482', 'e33b2489-2c7c-3de7-85a6-3b5da70b7a95', '8aa4213f-71fc-3683-9b8e-382d76f33f09', '4ef54e16-bea0-3679-a174-0d5da1fe14d4', '13841e73-eb54-30b5-ab96-c224cf93fab4', '63264adb-947a-354a-9991-38d8d72c844a', 'd25834c8-3d85-31dc-aa32-530c58c6be96', 'ea6825d6-575f-3575-a77e-8ef7c4d47233', '492ff0dd-aadd-3e7e-8a0d-1eb98923ff6e', 'b64dcb9b-a18c-32d1-ab15-53a78b1f85d7', '5d993b12-6829-3538-baed-3d683f646ba8', 'e6531548-7e44-399b-9cf8-66eae09d9535', 'b79888e7-a0b9-3303-bc15-b6b6d900fb23', '6e996298-9c41-3d8b-8851-b79aeb724792', 'cf1e8161-5d94-345e-aa32-04a49f95a4d7', '9d723973-21ae-3e35-af55-9078d8e6325b', '329a3ebb-96d7-3e02-b6b9-32bba921572b', '26c75fa1-0ea8-3e19-a2a4-3e041ff4a205', '5f4f3cdd-a291-35c1-b6c7-9c8e192b67b4', '0dae1911-c585-3081-b97e-d681c7f463a0', 'e32b6b5e-effc-3339-9894-3e183877d029', '631a7269-62e6-3185-9541-a2ec0ee57e32', 'fccb0366-cac6-3543-8c0f-1e02ef5228a2', '4ad4b87b-df40-368c-8a9a-04e41e009ce3', 'a60eeca2-6725-3078-b683-04f2fc8db99c', 'bf76cf38-5eab-3723-ac46-786a9fb80b60', '5c17adb4-b3f0-3118-8b70-ffaf632ff3fb', '823b0b8e-9522-37d9-881d-a6e57031c405', 'd9dc79e4-16ac-304e-8147-90c8a52858ac', 'd19fa135-dacd-3eb3-88a7-93032a1cf4ed',  ...
#     AP : All processes from in OpenLCA database
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size  : Members
#         None :     1 :    Any : 18268 : {'59e8d600-0acc-465d-8e6f-e092f03b1e52', '956ebeef-370e-34bb-ac83-11a10bba21d1', '90695e4b-05f9-3f41-b03d-93bef747469a', 'a1e42a9d-2e86-351b-a803-49a2392eb820', 'c9291945-f81f-3790-9a65-888287c32128', '9b9838d0-5ece-3ab4-b65d-296b158068fe', 'f1fb2132-52c2-4066-a0e1-4362bd745a86', 'b72a864d-7a48-354e-b439-0c97fd7a9932', 'a1ad566b-10fc-34eb-a2e4-16e2085167b4', 'a2a13850-cd09-305f-bfdd-426eab6c3333', '9ac82a23-f97f-316e-923b-b6d598126f43', 'e97e2560-8c11-42d7-8ee5-daa9ea4a7a3c', 'f1271c31-a654-428a-a3ab-66e252bfa236', '0d97dec0-7bdb-30b5-a57c-1f47fa4a3c2f', '3df247b5-3ae5-375e-978a-af57641b4402', '9c974dcd-f4e1-3100-81f6-6b2dfe0d12fc', '55d6f859-b134-3d97-84a0-788c97edca1b', '92510ace-bb13-409a-ac33-13e88273b466', 'e65c5b80-7929-4131-9560-0e351f540efb', '88328f20-4cae-4a28-904d-16f79dda688b', 'f9f7ecf6-d9a3-4b89-80f7-2619d82948c8', 'a6f840f3-28a2-31e0-b854-539382bb08ad', 'cd35ba47-c9bd-34b3-9b1b-83a6dfd88dfe', '040bf862-39e5-361f-b4df-64d5878de2ca', '95533fdb-a456-392d-a3fe-b8a4b00e7d4a', '6f530349-eaeb-4e29-af19-07739e574f1e', '22fbdfff-7dde-4234-bf13-499db46c6251', '670fbead-c441-493f-b6cb-80dff77ca187', '71048d7d-a21a-3aec-8b28-7fe7831f806e', '03ba967c-e301-3016-85be-1769dfaf57c3', '27e458c2-0fbf-4582-a6cb-410ac9d9e151', '441f3711-4934-3777-b59e-69718afa7eb1', '4dcd4698-99f0-39ee-bae6-4f4f5be8fd9a', 'f83a941d-fefc-3721-877e-8f1267a5d28e', '39804901-3e7d-342a-841b-a5245af8dbd8', '80df8495-41e7-3034-a1e3-967c95245c43', 'cc65e5d6-afa8-31d9-9ac4-3a0d9493f232', '6575a370-45d7-3b0c-b8b3-45e98d8290c6', 'c6fa8532-20a6-4d26-999f-bdf104b1b993', 'a637b21d-7ebf-4154-8863-36001d86cd54', '4ca6fd7d-a99b-4711-81ce-734f9fec0133', 'cbb21aaf-b710-3f83-9271-755b3eea792a', '79285a91-774d-3e3a-843d-d7e86c42492e', '2aafe315-4ff9-3917-9494-8d262958976f', 'c9f35ed9-afa4-3858-a636-d7e0347ee9f7', '7245f072-440c-3c77-a23f-a1e65e3850e0', '730314ca-ff04-3e00-8d1d-ed056ef591de', '9ac26fd2-08dc-3c69-884c-0f3163658a93', 'b824b353-1312-3ab0-93a2-90b4f7dd7e5d', 'bb7b5e9e-7386-44ed-85a9-c71d16e75ddb', '6b0c1a32-d075-409c-8bfc-b0d9d1105381', 'edf4544f-535c-41bd-b75e-321d0887f87c', '715461e4-4313-301d-8a3a-9623b00230f6', '5f6f7d6e-3607-4030-8569-4f777daa12a0', 'c4d8ed9c-282c-4f54-88fd-889ebfaa1189', 'bb7a2f25-2350-370d-a994-67321a7ee2bc', '00e88c84-0355-422e-9995-b1de04c5debd', 'f2a13d18-b316-315e-9539-5da5a7c2f358', 'a32cdfc3-e8fe-3aea-82ef-e5d7300329b2', '497cc89b-8571-3e84-9f12-09e79c4e8a4d', 'da61700f-ab7e-36bd-a6a2-165a7c76e51b', 'cac4eded-97d0-3fff-9a13-2fe49633e510', 'e1fa1120-1c53-3970-8eba-f014d0f89f4d', '5070595a-cb34-4b96-8a83-e9aba91875ed', '53835339-dbb9-3513-b63d-aa95414fc082', '083896cc-36c3-38a5-afd9-09d5366f2d8b', '28c7e3d1-7dba-420e-b50d-6fc32dfad2a0', 'ffe6fba0-8a92-3349-a3bc-2e83c149214b', 'efd80498-95f8-3767-94ee-8fabb5cb5509', '5426ee4a-69c7-46d8-acc0-81d3ee83ac71', '4e8b8145-9846-3c8b-9848-3a4afe6ec24a', '1951f6e3-dafd-3363-8fbe-8af62dfdd290', '1d88e60d-da20-3539-8015-a8909999ae7f', '7d7b8016-b3e6-33fe-86fd-ffbe7e25a09b', '07fa5891-acda-3bea-91a5-15e9da79a8f1', 'c43b2f90-dda5-3a73-abbd-932833929e40', '6087ef4a-1762-3efe-8119-a4c407b6c5c6', 'ab64a96d-d2b8-4bea-8c39-fc3ffaff0670', 'cfdd239d-051d-3cc1-9df4-76299f81bc7d', 'f47824f3-33aa-44c6-a2a1-348a27d8cd02', '38633540-096f-3fce-a2de-ebc1a49a682a', '41f99d41-cf02-4b8c-a1d1-f16af0271bc6', '3e025a90-664c-3694-9259-a720ad2d1fff', '47eacb90-3e45-3034-bdb1-de9d89ad7df2', '61d34f09-545a-3815-ab00-d127079d7c48', '0a7e9727-e58d-33a0-a2ca-98577a607fad', 'f27a2b6b-b330-3772-a124-6199fcaf6600', 'f1ea8fc1-0eea-378f-bfd6-a803d0290ac4', 'eb3ff866-3a8c-43e5-b20a-f8930936dbd0', 'f94c1ad1-2f56-3019-a0dc-2ea2f40f688c', 'f238fbf5-645d-3304-b4ae-82b47eec9ea9', '7a117930-065b-3ae6-9767-e572402b0e50', 'bf4e3ad6-d6d6-3b66-9c54-fd31ae084736', '1c1046aa-5822-34fd-8c4b-350f94efe9a4', '5bab02e2-687e-4b8a-96be-1bb00eb29521', '4c87fa97-9c62-34fc-9289-f30a32f7c02b', '230e73d0-7163-3dcf-9d94-fbeb9feaaeba', '4140b7b5-43c2-3754-a26e-6c6cd88f4c00', '2696f92b-d325-37ad-94ce-bcdbf0c1e600', ...
#     C_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain  : Size : Members
#         None :     3 : F_m*K*T :    2 : {('f1', 'k1', 't1'), ('f2', 'k1', 't1')}
#     D : Demands
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    1 : {'d1',}
#     Demand_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     3 :  D*K*T :    1 : {('d1', 'k1', 't1'),}
#     E : Elementary Flows in OpenLCA database
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any : 3930 : {'0f440cc0-0f74-446d-99d6-8ff0e97a2444', 'e336eee7-148a-4d1c-8027-780cbfafa12b', 'e6551223-73b6-4289-b841-c5cdeb25abd9', '33b38ccb-593b-4b11-b965-10d747ba3556', 'afd6d670-bbb0-4625-9730-04088a5b035e', '70ef743b-3ed5-4a6d-b192-fb6d62378555', '66f50b33-fd62-4fdd-a373-c5b0de7de00d', '099b36ab-4c03-4587-87f4-2f81e337afb8', 'aa7cac3a-3625-41d4-bc54-33e2cf11ec46', '4d40d8e3-9bc7-4ab1-ac5c-4f4a76fda8e5', 'ada3ecfe-8244-4389-bcce-e83ca4f66e09', '81c4ba39-8a3f-4a43-97b4-401605bbebf5', '13d898ac-b9be-4723-a153-565e2a9144ac', '77357947-ccc5-438e-9996-95e65e1e1bce', '5e883a00-04e6-4d96-8dce-12d7117c6635', 'e8fc62ba-678e-4706-97d2-b79d83e227d5', '78c3efe4-421c-4d30-82e4-b97ac5124993', 'e2d58f90-9aac-4ac4-87f7-bbd6cfc358e3', '78eb1859-abd9-44c6-9ce3-f3b5b33d619c', '68b9b577-90cf-49e4-88bb-a55d80f3ac5d', '0d3ccb17-b3fe-4c08-b7cb-458ed3ababf1', 'fc9f9a81-c4b9-4dce-bc20-9f04e05ca2f1', '7a2d7097-20c4-4b5f-b2ee-bcfc2ba1378f', 'c5cc0625-6e01-4639-b053-5d1d9d22a53c', 'f7553ef8-e4f3-4b9c-98be-81fa36315648', '10b69d7a-018d-44c6-9a5e-e67fc9475b86', '23856318-9583-426b-ab04-12e4506b60a8', '9beb60a3-3a8c-4345-9a0e-107eec2f709f', '295c9740-6fdb-4676-9eb8-15e3786f713d', '63974d2c-11f3-45eb-be9c-726261b04d85', 'a1d277aa-7aea-4b5e-8aa9-2789ba8ff333', '77f17646-cede-4a49-99dd-55950098b077', 'bf633941-aa40-4c37-b361-b5cbfb1089f5', '9541a975-800f-4fed-9edf-28f6e411a015', '1d2439de-751b-469a-ba3e-fda8fe9802b2', 'e7e0031e-791d-42f4-b26c-ec322db637bc', '87f683ed-44ae-41a6-b4bc-230622f8cfef', '9167dca7-615e-435c-8ba6-dbbf50e50e34', 'e64254e3-07d3-4330-b6de-6a858f108124', '142ce3b0-4bd6-47a3-9991-7c657c947ffe', '9e8d685c-9948-4dc0-9c0b-d5c511e14d05', 'e0e605c8-370b-4b5a-b6d4-2e7a5a1a6709', 'e7f7fd97-a1c8-4be9-8a21-68ef06437d20', '0437e787-ef47-4a50-b11f-df7c743e860c', 'd24f41d7-279e-4f5a-9ac9-00f726dc3bcc', 'f77c5e36-ee47-4437-b757-03139bb1d6d6', 'ba5fc0b6-770b-4da1-9b3f-e3b5087f07cd', '03b279a7-4626-4703-a451-d0650599dbd9', 'b821ad93-ba6a-4d74-b6ae-ca12cd9563d7', 'dc46afa7-0142-49e8-a353-ab6a1327bbc8', '3d719c07-ec27-4971-b7cc-4bcf17d77dd3', 'a028cff8-e405-4d44-8322-f46e9e51bcdc', 'c76ddd9e-fd9c-47c5-9b95-ad924146f0bb', '9597c1a2-ecda-4a89-97c5-efcdc679058d', '2460f868-54a9-404c-bec8-c809a44ae72c', '7348af7c-e102-4a03-a0df-efce16469eed', '2d50f4c8-a917-4496-a7d9-470b080faf68', '5ec9c16a-959d-44cd-be7d-a935727d2151', '15fd8f0f-c3c2-4f63-b8d0-86793a22aacd', '2718482b-8399-442e-b89a-52fbcc22d2e6', 'd6235194-e4e6-4548-bfa3-ac095131aef4', 'ea4e9316-5080-4b3b-bbf3-1949f6d7577a', '17a98e7f-a8fd-431d-9bb6-6c4bf3fc5517', 'b8d738ce-98cd-4487-88f9-686209bd1376', 'd32f9dd8-9514-4c22-8c99-2e108609731f', '57bdb443-d4a6-423d-8024-959b8261d02e', '09872080-d143-4fb1-a3a5-647b077107ff', '075e433b-4be4-448e-9510-9a5029c1ce94', '21b46c65-491e-40a9-ac74-5877af997d7c', 'b967e1bf-f09b-4c89-8740-ace21db47bba', '71234253-b3a7-4dfe-b166-a484ad15bee7', 'c1b91234-6f24-417b-8309-46111d09c457', 'fd7aa71c-508c-480d-81a6-8052aad92646', '5d368100-b1bc-4456-8420-e469edccf349', '66020d27-7ae4-4e59-83a3-89214b72c40a', '21e46cb8-6233-4c99-bac3-c41d2ab99498', 'c941d6d0-a56c-4e6c-95de-ac685635218d', '082903e4-45d8-4078-94cb-736b15279277', '4841a0fe-c250-4a39-94a1-1bc31426c0f1', '39d1390a-ded6-41cb-a536-d47510bf2fbc', 'd14eb0da-95fd-46c3-90db-55ca33d78701', '20d4d821-f4f7-4017-8810-f822fcdf619e', 'd761f94e-517d-41cf-89fa-17dc72f7a69b', '24541c8c-9f11-49ae-9de5-456f238a3f5e', '87883a4e-1e3e-4c9d-90c0-f1bea36f8014', '20185046-64bb-4c09-a8e7-e8a9e144ca98', '2058d91e-bb9f-4fce-8e53-131825b14a23', '35d1dff5-b535-4628-9826-4a8fce08a1f2', 'ba2f3f82-c93a-47a5-822a-37ec97495275', 'd3260d0e-8203-4cbb-a45a-6a13131a5108', '0795345f-c7ae-410c-ad25-1845784c75f5', '7678cec7-b8e1-439d-8242-99cd452834b1', '349b29d1-3e58-4c66-98b9-9d1a076efd2e', 'f2d84834-d0b3-42e5-b41a-f04cc80337a4', '81e17d9a-3e0b-414e-9b2e-eca7e5b3bd4a', '20557d93-2b1c-49b5-b6c0-3528a8bbc307', '591b0a62-8064-4697-86ed-47bfa1f8b5e6', '1c5a7322-9261-4d59-a692-adde6c12de92', 'f0e28a62-ddf9-4c93-af81-676a58c3f2d4',  ...
#     EI_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain  : Size : Members
#         None :     3 : KPI*F*P :    4 : {('kpi1', 'f1', 'p1'), ('kpi1', 'f2', 'p1'), ('kpi1', 'fs1', 'p1'), ('kpi1', 'ft1', 'p1')}
#     F : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain          : Size : Members
#         None :     1 : F_index_0 | F_s :    4 : {'f1', 'f2', 'fs1', 'ft1'}
#     F_index_0 : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain    : Size : Members
#         None :     1 : F_m | F_t :    3 : {'f1', 'f2', 'fs1'}
#     F_m : Material flows to optimise
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    2 : {'f1', 'f2'}
#     F_s : Service flows to optimise
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    1 : {'ft1',}
#     F_t : Transport flows to optimise
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    1 : {'fs1',}
#     Flow_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain    : Size : Members
#         None :     4 : F_m*P*K*T :    2 : {('f1', 'p1', 'k1', 't1'), ('f2', 'p1', 'k1', 't1')}
#     K : Tasks
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    1 : {'k1',}
#     KPI : Performance indicators for optimisation problem
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    1 : {'kpi1',}
#     L_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain  : Size : Members
#         None :     2 : F_m*F_t :    2 : {('f1', 'fs1'), ('f2', 'fs1')}
#     P : Processes in the optimisation problem
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    1 : {'p1',}
#     Service_Flow_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain    : Size : Members
#         None :     4 : F_s*P*K*T :    1 : {('ft1', 'p1', 'k1', 't1'),}
#     Specific_Material_Transport_Flow_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain        : Size : Members
#         None :     5 : F_m*P*F_t*K*T :    2 : {('f1', 'p1', 'fs1', 'k1', 't1'), ('f2', 'p1', 'fs1', 'k1', 't1')}
#     Specific_Transport_Flow_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain    : Size : Members
#         None :     4 : F_t*P*K*T :    1 : {('fs1', 'p1', 'k1', 't1'),}
#     Storage_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain  : Size : Members
#         None :     3 : F_s*K*T :    1 : {('ft1', 'k1', 't1'),}
#     T : Time intervals
#         Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    1 : {'t1',}
#     Total_Demand_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    D*K :    1 : {('d1', 'k1'),}
#     Transport_Flow_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain  : Size : Members
#         None :     3 : F_t*K*T :    1 : {('fs1', 'k1', 't1'),}
#     X_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    K*T :    1 : {('k1', 't1'),}
#     Y_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    K*T :    1 : {('k1', 't1'),}
#     d_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain    : Size : Members
#         None :     4 : P*F_m*K*T :    2 : {('p1', 'f1', 'k1', 't1'), ('p1', 'f2', 'k1', 't1')}
#     material_flow_constraint_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain    : Size : Members
#         None :     4 : F_m*P*K*T :    2 : {('f1', 'p1', 'k1', 't1'), ('f2', 'p1', 'k1', 't1')}
#     phi_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     3 :  F*P*T :    4 : {('f1', 'p1', 't1'), ('f2', 'p1', 't1'), ('fs1', 'p1', 't1'), ('ft1', 'p1', 't1')}
#     specific_transport_constraint_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain  : Size : Members
#         None :     3 : F_t*K*T :    1 : {('fs1', 'k1', 't1'),}
#     total_demand_constraint_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    D*K :    1 : {('d1', 'k1'),}
#     transport_constraint_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain  : Size : Members
#         None :     3 : F_t*K*T :    1 : {('fs1', 'k1', 't1'),}
#
# 9 Param Declarations
#     C : Conversion factor for material flows
#         Size=2, Index=C_index, Domain=Any, Default=None, Mutable=False
#         Key                : Value
#         ('f1', 'k1', 't1') :     2
#         ('f2', 'k1', 't1') :     2
#     Demand : Size=0, Index=Demand_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#     EI : Size=4, Index=EI_index, Domain=Any, Default=None, Mutable=False
#         Key                   : Value
#          ('kpi1', 'f1', 'p1') :     1
#          ('kpi1', 'f2', 'p1') :     1
#         ('kpi1', 'fs1', 'p1') :     1
#         ('kpi1', 'ft1', 'p1') :     1
#     L : Size=0, Index=L_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#     Total_Demand : Size=1, Index=Total_Demand_index, Domain=Any, Default=None, Mutable=False
#         Key          : Value
#         ('d1', 'k1') :     1
#     X : Size=0, Index=X_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#     Y : Size=0, Index=Y_index, Domain=Any, Default=None, Mutable=False
#         Key : Value
#     d : Size=2, Index=d_index, Domain=Any, Default=None, Mutable=False
#         Key                      : Value
#         ('p1', 'f1', 'k1', 't1') :     2
#         ('p1', 'f2', 'k1', 't1') :     2
#     phi : Size=4, Index=phi_index, Domain=Any, Default=None, Mutable=False
#         Key                 : Value
#          ('f1', 'p1', 't1') :     1
#          ('f2', 'p1', 't1') :     1
#         ('fs1', 'p1', 't1') :     1
#         ('ft1', 'p1', 't1') :     1
#
# 6 Var Declarations
#     Flow : Size=2, Index=Flow_index
#         Key                      : Lower : Value : Upper : Fixed : Stale : Domain
#         ('f1', 'p1', 'k1', 't1') :  None :  None :  None : False :  True :  Reals
#         ('f2', 'p1', 'k1', 't1') :  None :  None :  None : False :  True :  Reals
#     Service_Flow : Size=1, Index=Service_Flow_index
#         Key                       : Lower : Value : Upper : Fixed : Stale : Domain
#         ('ft1', 'p1', 'k1', 't1') :  None :  None :  None : False :  True :  Reals
#     Specific_Material_Transport_Flow : Size=2, Index=Specific_Material_Transport_Flow_index
#         Key                             : Lower : Value : Upper : Fixed : Stale : Domain
#         ('f1', 'p1', 'fs1', 'k1', 't1') :  None :  None :  None : False :  True :  Reals
#         ('f2', 'p1', 'fs1', 'k1', 't1') :  None :  None :  None : False :  True :  Reals
#     Specific_Transport_Flow : Size=1, Index=Specific_Transport_Flow_index
#         Key                       : Lower : Value : Upper : Fixed : Stale : Domain
#         ('fs1', 'p1', 'k1', 't1') :  None :  None :  None : False :  True :  Reals
#     Storage : Size=1, Index=Storage_index
#         Key                 : Lower : Value : Upper : Fixed : Stale : Domain
#         ('ft1', 'k1', 't1') :  None :  None :  None : False :  True :  Reals
#     Transport_Flow : Size=1, Index=Transport_Flow_index
#         Key                 : Lower : Value : Upper : Fixed : Stale : Domain
#         ('fs1', 'k1', 't1') :  None :  None :  None : False :  True :  Reals
#
# 2 Objective Declarations
#     obj1 : Size=1, Index=KPI, Active=True
#         Key  : Active : Sense    : Expression
#         kpi1 :   True : minimize : Flow[f1,p1,k1,t1] + Flow[f2,p1,k1,t1] + Service_Flow[ft1,p1,k1,t1] + Specific_Transport_Flow[fs1,p1,k1,t1]
#     obj2 : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : Flow[f1,p1,k1,t1] + Flow[f2,p1,k1,t1] + Service_Flow[ft1,p1,k1,t1] + Specific_Transport_Flow[fs1,p1,k1,t1]
#
# 4 Constraint Declarations
#     material_flow_constraint : Size=2, Index=material_flow_constraint_index, Active=True
#         Key                      : Lower : Body                                                                  : Upper : Active
#         ('f1', 'p1', 'k1', 't1') :   0.0 : Flow[f1,p1,k1,t1] - Specific_Material_Transport_Flow[f1,p1,fs1,k1,t1] :   0.0 :   True
#         ('f2', 'p1', 'k1', 't1') :   0.0 : Flow[f2,p1,k1,t1] - Specific_Material_Transport_Flow[f2,p1,fs1,k1,t1] :   0.0 :   True
#     specific_transport_constraint : Size=1, Index=specific_transport_constraint_index, Active=True
#         Key                 : Lower : Body                                                              : Upper : Active
#         ('fs1', 'k1', 't1') :   0.0 : Transport_Flow[fs1,k1,t1] - Specific_Transport_Flow[fs1,p1,k1,t1] :   0.0 :   True
#     total_demand_constraint : Size=1, Index=total_demand_constraint_index, Active=True
#         Key          : Lower : Body                                      : Upper : Active
#         ('d1', 'k1') :   1.0 : 2*Flow[f1,p1,k1,t1] + 2*Flow[f2,p1,k1,t1] :  +Inf :   True
#     transport_constraint : Size=1, Index=transport_constraint_index, Active=True
#         Key                 : Lower : Body                                                                                                                                    : Upper : Active
#         ('fs1', 'k1', 't1') :   0.0 : Transport_Flow[fs1,k1,t1] - (2*Specific_Material_Transport_Flow[f1,p1,fs1,k1,t1] + 2*Specific_Material_Transport_Flow[f2,p1,fs1,k1,t1]) :   0.0 :   True
#
# 54 Declarations: F_m F_s F_t F_index_0 F P T K D KPI AF E AP AKPI C_index C Demand_index Demand Total_Demand_index Total_Demand L_index L X_index X Y_index Y d_index d phi_index phi EI_index EI Flow_index Flow Storage_index Storage Service_Flow_index Service_Flow Specific_Material_Transport_Flow_index Specific_Material_Transport_Flow Transport_Flow_index Transport_Flow Specific_Transport_Flow_index Specific_Transport_Flow obj1 obj2 total_demand_constraint_index total_demand_constraint material_flow_constraint_index material_flow_constraint transport_constraint_index transport_constraint specific_transport_constraint_index specific_transport_constraint

# %% [markdown]
# Using introspection we can examine the contents of the populated sets.

# %%
import pandas as pd
dfr = pd.DataFrame(
    ([v.name, v.doc, len(v)] for v in model_instance.component_data_objects(Set, active=True)),
    columns=['Set', 'Description', 'Number of elements']
)
dfr
# Out:
#                                        Set  \
# 0                                      F_m
# 1                                      F_s
# 2                                      F_t
# 3                                F_index_0
# 4                                        F
# 5                                        P
# 6                                        T
# 7                                        K
# 8                                        D
# 9                                      KPI
# 10                                      AF
# 11                                       E
# 12                                      AP
# 13                                    AKPI
# 14                                 C_index
# 15                            Demand_index
# 16                      Total_Demand_index
# 17                                 L_index
# 18                                 X_index
# 19                                 Y_index
# 20                                 d_index
# 21                               phi_index
# 22                                EI_index
# 23                              Flow_index
# 24                           Storage_index
# 25                      Service_Flow_index
# 26  Specific_Material_Transport_Flow_index
# 27                    Transport_Flow_index
# 28           Specific_Transport_Flow_index
# 29           total_demand_constraint_index
# 30          material_flow_constraint_index
# 31              transport_constraint_index
# 32     specific_transport_constraint_index
#
#                                           Description  Number of elements
# 0                          Material flows to optimise                   2
# 1                           Service flows to optimise                   1
# 2                         Transport flows to optimise                   1
# 3                                                None                   3
# 4                                                None                   4
# 5               Processes in the optimisation problem                   1
# 6                                      Time intervals                   1
# 7                                               Tasks                   1
# 8                                             Demands                   1
# 9     Performance indicators for optimisation problem                   1
# 10                      All flows in openLCA database                7033
# 11               Elementary Flows in OpenLCA database                3930
# 12             All processes from in OpenLCA database               18268
# 13  All key performance indicators in an openLCA d...                 878
# 14                                               None                   2
# 15                                               None                   1
# 16                                               None                   1
# 17                                               None                   2
# 18                                               None                   1
# 19                                               None                   1
# 20                                               None                   2
# 21                                               None                   4
# 22                                               None                   4
# 23                                               None                   2
# 24                                               None                   1
# 25                                               None                   1
# 26                                               None                   2
# 27                                               None                   1
# 28                                               None                   1
# 29                                               None                   1
# 30                                               None                   2
# 31                                               None                   1
# 32                                               None                   1

# %% [markdown]
# We can also see the concrete constraints.

# %%
dfr = pd.DataFrame(
    ([v.name, v.expr] for v in model_instance.component_data_objects(Constraint, active=True)),
    columns=['Constraint', 'Expression']
)
qgrid.show_grid(dfr)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# We can also need to see the objectives.

# %%
dfr = pd.DataFrame(
    ([v.name, v.expr] for v in model_instance.component_data_objects(Objective, active=True)),
    columns=['Objective', 'Expression']
)

qgrid.show_grid(dfr)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
